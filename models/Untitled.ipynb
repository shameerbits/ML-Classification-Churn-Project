# %%
import joblib
import sys
import os
sys.path.append(os.path.abspath(".."))
from preprocessing import blank_to_nan, normalize_strings, coerce_numeric

model = joblib.load("../models/logistic.pkl")
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
import pandas as pd

df = pd.read_csv("../dataset/telco_test.csv")
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      72          Yes
# 1  Female              1      No         No       8          Yes
# 2  Female              0     Yes        Yes      41          Yes
# 3    Male              0     Yes         No      18          Yes
# 4  Female              0     Yes         No      72          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0           Yes     Fiber optic            Yes          Yes              Yes
# 1           Yes     Fiber optic             No           No               No
# 2           Yes             DSL            Yes          Yes              Yes
# 3            No     Fiber optic             No           No              Yes
# 4           Yes             DSL            Yes          Yes              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes             Yes        Two year              Yes
# 1         Yes         Yes             Yes  Month-to-month              Yes
# 2          No         Yes              No        One year              Yes
# 3         Yes          No              No  Month-to-month               No
# 4          No         Yes             Yes        Two year              Yes
#
#              PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  Credit card (automatic)          114.05       8468.2    No
# 1  Credit card (automatic)          100.15       908.55    No
# 2  Credit card (automatic)           78.35       3211.2    No
# 3         Electronic check           78.20      1468.75    No
# 4  Credit card (automatic)           82.65      5919.35    No

# %%
X = df.drop(columns=["Churn"])
y = df["Churn"].map({"No": 0, "Yes": 1})

y_pred = model.predict(X)
print("Prediction works")
# Out:
# Prediction works

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

print("Accuracy:", accuracy_score(y, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y, y_pred))
# Out:
# Accuracy: 0.7402413058907026
# Confusion Matrix:
# [[748 287]
#  [ 79 295]]

# %%
import streamlit as st

# %%
import sklearn
st.write("Sklearn version:", sklearn.__version__)
st.write("Model type:", type(model))
st.write("Model attributes:", model.__dict__.keys())
# Out:
# 2026-01-24 22:49:17.903 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.677
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\mparakkottm2\PycharmProjects\telcochurn\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-01-24 22:49:18.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-24 22:49:18.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.8.0
# Summary: A set of python modules for machine learning and data mining
# Home-page:
# Author:
# Author-email:
# License:
# Location: C:\Users\mparakkottm2\PycharmProjects\telcochurn\.venv\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
